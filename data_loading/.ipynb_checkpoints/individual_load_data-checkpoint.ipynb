# %%
from nilmtk.dataset_converters import convert_ampds
from nilmtk import DataSet
from nilmtk.utils import print_dict
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
ampds = DataSet("../data/load_profile/AMPds2.h5")
print(ampds.buildings)
elec = ampds.buildings[1].elec
item = 18
tv = elec.meters.__getitem__(item)
print(tv)
ax = tv.plot()
print(tv)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-73326a034b09> in <module>
# ----> 1 ampds = DataSet("../data/AMPds2.h5")
#       2 print(ampds.buildings)
#       3 elec = ampds.buildings[1].elec
#       4 item = 18
#       5 tv = elec.meters.__getitem__(item)
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/nilmtk/dataset.py in __init__(self, filename, format)
#      42         self.metadata = {}
#      43         if filename is not None:
# ---> 44             self.import_metadata(get_datastore(filename, format))
#      45
#      46     def import_metadata(self, store):
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/nilmtk/utils.py in get_datastore(filename, format, mode)
#     315     if filename is not None:
#     316         if format == 'HDF':
# --> 317             return HDFDataStore(filename, mode)
#     318         elif format == 'CSV':
#     319             return CSVDataStore(filename)
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/nilmtk/docinherit.py in f(*args, **kwargs)
#      44         @wraps(self.mthd, assigned=('__name__', '__module__'))
#      45         def f(*args, **kwargs):
# ---> 46             return self.mthd(obj, *args, **kwargs)
#      47
#      48         return self.use_parent_doc(f, overridden)
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/nilmtk/datastore/hdfdatastore.py in __init__(self, filename, mode)
#      16     def __init__(self, filename, mode='a'):
#      17         if mode == 'a' and not isfile(filename):
# ---> 18             raise IOError("No such file as " + filename)
#      19
#      20         with warnings.catch_warnings():
#
# OSError: No such file as ../data/AMPds2.h5

# %%
for item in range(1,20):
    elec = ampds.buildings[1].elec
    tv = elec.meters.__getitem__(item)
    print(tv)
    print(tv.appliances[0].metadata.get('original_name'))
    ax = tv.plot()
    ax.legend(title=tv.appliances[0].metadata.get('original_name'))
# Out:
# ElecMeter(instance=2, building=1, dataset='AMPds', appliances=[Appliance(type='light', instance=1)])
# B1E
# ElecMeter(instance=3, building=1, dataset='AMPds', appliances=[Appliance(type='light', instance=2)])
# B2E
# ElecMeter(instance=4, building=1, dataset='AMPds', appliances=[Appliance(type='light', instance=3)])
# BME
# ElecMeter(instance=5, building=1, dataset='AMPds', appliances=[Appliance(type='unknown', instance=1)])
# CDE
# ElecMeter(instance=6, building=1, dataset='AMPds', appliances=[Appliance(type='unknown', instance=2)])
# CWE
# ElecMeter(instance=7, building=1, dataset='AMPds', appliances=[Appliance(type='sockets', instance=1)])
# DNE
# ElecMeter(instance=8, building=1, dataset='AMPds', appliances=[Appliance(type='unknown', instance=3)])
# DWE
# ElecMeter(instance=9, building=1, dataset='AMPds', appliances=[Appliance(type='unknown', instance=4)])
# EBE
# ElecMeter(instance=10, building=1, dataset='AMPds', appliances=[Appliance(type='unknown', instance=5)])
# EQE
# ElecMeter(instance=11, building=1, dataset='AMPds', appliances=[Appliance(type='fridge', instance=1)])
# FGE
# ElecMeter(instance=12, building=1, dataset='AMPds', appliances=[Appliance(type='unknown', instance=6)])
# FRE
# ElecMeter(instance=13, building=1, dataset='AMPds', appliances=[Appliance(type='unknown', instance=7)])
# GRE
# ElecMeter(instance=14, building=1, dataset='AMPds', appliances=[Appliance(type='heat pump', instance=1)])
# HPE
# ElecMeter(instance=15, building=1, dataset='AMPds', appliances=[Appliance(type='unknown', instance=8)])
# HTE
# ElecMeter(instance=16, building=1, dataset='AMPds', appliances=[Appliance(type='light', instance=4)])
# OFE
# ElecMeter(instance=17, building=1, dataset='AMPds', appliances=[Appliance(type='sockets', instance=2)])
# OUE
# ElecMeter(instance=18, building=1, dataset='AMPds', appliances=[Appliance(type='unknown', instance=9)])
# RSE
# ElecMeter(instance=19, building=1, dataset='AMPds', appliances=[Appliance(type='television', instance=1)])
# TVE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1a9a34851f0c> in <module>
#       4     print(tv)
#       5     print(tv.appliances[0].metadata.get('original_name'))
# ----> 6     ax = tv.plot()
#       7     ax.legend(title=tv.appliances[0].metadata.get('original_name'))
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/nilmtk/electric.py in plot(self, ax, timeframe, plot_legend, unit, plot_kwargs, **kwargs)
#     177         kwargs['sections'] = [timeframe]
#     178         kwargs = self._set_sample_period(timeframe, **kwargs)
# --> 179         power_series = self.power_series_all_data(**kwargs)
#     180         if power_series is None or power_series.empty:
#     181             return ax
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/nilmtk/electric.py in power_series_all_data(self, **kwargs)
#     103     def power_series_all_data(self, **kwargs):
#     104         chunks = []
# --> 105         for series in self.power_series(**kwargs):
#     106             if len(series) > 0:
#     107                 chunks.append(series)
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/nilmtk/electric.py in load_series(self, **kwargs)
#     624         physical_quantity = kwargs['physical_quantity']
#     625         generator = self.load(**kwargs)
# --> 626         for chunk in generator:
#     627             if chunk.empty:
#     628                 yield chunk
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/nilmtk/preprocessing/apply.py in process(self)
#      11     def process(self):
#      12         self.check_requirements()
# ---> 13         for chunk in self.upstream.process():
#      14             new_chunk = self.func(chunk)
#      15             new_chunk.timeframe = chunk.timeframe
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/nilmtk/datastore/hdfdatastore.py in load(self, key, columns, sections, n_look_ahead_rows, chunksize, verbose)
#      82             else:
#      83                 try:
# ---> 84                     coords = self.store.select_as_coordinates(key=key, where=terms)
#      85                 except AttributeError as e:
#      86                     if str(e) == ("'NoneType' object has no attribute "
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/pandas/io/pytables.py in select_as_coordinates(self, key, where, start, stop, **kwargs)
#     731         where = _ensure_term(where, scope_level=1)
#     732         return self.get_storer(key).read_coordinates(where=where, start=start,
# --> 733                                                      stop=stop, **kwargs)
#     734
#     735     def select_column(self, key, column, **kwargs):
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/pandas/io/pytables.py in read_coordinates(self, where, start, stop, **kwargs)
#    3696         self.selection = Selection(
#    3697             self, where=where, start=start, stop=stop, **kwargs)
# -> 3698         coords = self.selection.select_coords()
#    3699         if self.selection.filter is not None:
#    3700             for field, op, filt in self.selection.filter.format():
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/pandas/io/pytables.py in select_coords(self)
#    4758             return self.table.table.get_where_list(self.condition.format(),
#    4759                                                    start=start, stop=stop,
# -> 4760                                                    sort=True)
#    4761         elif self.coordinates is not None:
#    4762             return self.coordinates
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/tables/table.py in get_where_list(self, condition, condvars, sort, start, stop, step)
#    1607
#    1608         coords = [p.nrow for p in
# -> 1609                   self._where(condition, condvars, start, stop, step)]
#    1610         coords = numpy.array(coords, dtype=SizeType)
#    1611         # Reset the conditions
#
# ~/.conda/envs/nilmtk-env/lib/python3.6/site-packages/tables/table.py in <listcomp>(.0)
#    1606         self._g_check_open()
#    1607
# -> 1608         coords = [p.nrow for p in
#    1609                   self._where(condition, condvars, start, stop, step)]
#    1610         coords = numpy.array(coords, dtype=SizeType)
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-43b30c582dd6> in <module>
# ----> 1 ampds.climate
#
# AttributeError: 'DataSet' object has no attribute 'climate'
