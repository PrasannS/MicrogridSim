# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pv = pd.read_csv('../data/solar/Actual_44.05_-92.45_2006_DPV_20MW_5_Min.csv')

# %%
pv.describe()
# Out:
#            Power(MW)
# count  105120.000000
# mean        2.651255
# std         4.191461
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         4.200000
# max        18.000000

# %%
#power output for 1 day
#weather data not directly provided, but state / location is provided so this can be deciphered later on
#for now this should suffice since location / timing is close to ampds
plt.plot(pv['Power(MW)'].iloc[0:288])

# %%
plt.plot(pv['Power(MW)'])

# %%
wind = pd.read_csv('../data/wind/wind_data.csv')

# %%
wind
# Out:
#               Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0      01 01 2018 00:00           380.047791          5.311336
# 1      01 01 2018 00:10           453.769196          5.672167
# 2      01 01 2018 00:20           306.376587          5.216037
# 3      01 01 2018 00:30           419.645905          5.659674
# 4      01 01 2018 00:40           380.650696          5.577941
# ...                 ...                  ...               ...
# 50525  31 12 2018 23:10          2963.980957         11.404030
# 50526  31 12 2018 23:20          1684.353027          7.332648
# 50527  31 12 2018 23:30          2201.106934          8.435358
# 50528  31 12 2018 23:40          2515.694092          9.421366
# 50529  31 12 2018 23:50          2820.466064          9.979332
#
#        Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                         416.328908          259.994904
# 1                         519.917511          268.641113
# ...

# %%
wind.columns
# Out:
# Index(['Date/Time', 'LV ActivePower (kW)', 'Wind Speed (m/s)',
#        'Theoretical_Power_Curve (KWh)', 'Wind Direction (°)'],
#       dtype='object')
