# %%
import simpy
import random
import statistics
import pandas as pd
import numpy as np
import json

# %%
house_params = {
    'television_power':10,
    'ac_power':10,
}
with open('house_params.json', 'w') as fp:
    json.dump(house_params, fp)

# %%
params = json.load(open(('house_params.json')))
params
# Out:
# {'television_power': 10, 'ac_power': 10}

# %%
class House(object):
    
    #switch control for AC
    air_condition = False
    fridge = True
    heat_pump = True
    #consumption of power by appliances on time step
    lights = 0
    
    #power_consumption parameters
    television_power = 10
    microwave_power = 4
    air_condition_power = 30
    fridge_power = 14
    heat_pump_power = 20
    
    #state variables, not sure abt water temp
    water_temp = 30
    water_target = 40
    home_temp = 28
    target_temp = 27
    fridge_temp = 10
    fridge_target = 5
    
    #set up as the duration left that appliance n is running, 0 means it is off
    microwave= 0
    television = 4

    net_load = 0
    power_thresh = 200
    
    def __init__(self, env, json_path):
        self.env = env
        params = json.load(open(json_path))
        print(str(params))
        try:
            
            #power_consumption parameters
            television_power = params['television_power']
            microwave_power = params['microwave_power']
            air_condition_power = params['air_condition_power']
            fridge_power = params['fridge_power']
            heat_pump_power = params['heat_pump_power']

            #state variables, not sure abt water temp
            water_temp = params['water_temp']
            water_target = params['water_target']
            home_temp = params['home_temp']
            target_temp = params['target_temp']
            fridge_temp = params['fridge_temp']
            fridge_target = params['fridge_target']
        except:
            print("some or all parameters are missing")
            

    def get_event_power(self):

            if self.television != 0:
                #print("TELEVISION "+str(self.television))
                self.television=self.television-1
            #this should be modified to match actual probability distribution
            elif random.randint(1, 20)>19:
                #TODO w prob distribution
                self.television = random.randint(300, 7200)
                print("tv turned on for "+ str(self.television/60)+ " minutes")
            if self.microwave!=0:
                self.microwave-=1
            elif random.randint(1, 5)>4:
                #TODO w prob distribution
                self.microwave = random.randint(30, 500)
                #print("microwave turned on for "+ str(self.microwave/60)+ " minutes")

            return self.television_power+self.microwave_power

    def get_reccuring_power(self):

        load = 0
        if self.air_condition:
            load+= self.air_condition_power
            self.home_temp-=0.0025
            if self.home_temp<self.target_temp:
                self.air_condition = False
        else:
            if self.home_temp>self.target_temp:  
                #print("ac turned on")
                self.air_condition = True
            self.home_temp+=0.0045
            #TODO w prob distribution

            #print("AC turned on")
        if self.fridge:
            load+= self.fridge_power
            self.fridge_temp-=0.0025
            if self.fridge_temp<self.fridge_temp:
                self.fridge = False
        else:
            if self.fridge_temp>self.fridge_target:  
                self.fridge = True
            self.fridge_temp+=0.0045
            #TODO w prob distribution

            #print("Fridge turned on")
        if self.heat_pump:
            load+= self.heat_pump_power
            self.water_temp+=0.025
            if self.water_temp>self.water_target:
                self.heat_pump = False
        else:
            if self.fridge_temp>self.fridge_target:  
                self.heat_pump = True
            self.water_temp-=0.025
            #TODO w prob distribution

            #print("Heat Pump turned on")

        return load

    def get_light_power(self):
        #needs to be matched to lights prob distribution given time of day

        self.lights = random.randint(10, 20)
        return self.lights

    def run_load(self):
        #print("Next")
        self.net_load = 0
        self.net_load+=self.get_event_power()
        self.net_load+=self.get_reccuring_power()
        self.net_load+=self.get_light_power()
        #print("LOAD IS"+str(self.net_load))
        return self.net_load

# %%
#Measurements / Observations
# 
'''
1 week of simulation with 10 loads takes roughly 22-23 seconds on my computer
1 day with 10 loads takes roughly 3 seconds

With the current buy / sell model (no battery) the price either skews to the left 
or the right, so it's a bit tougher to make highly consistent

AC stays almost consistently on to maintain exact temperature, but if pushed to degree
or a smaller precision power / ac time can be saved significantly

Load modelling seems to be relatively functional. Controls will be maintained for only 
sections of the load modelling, such as AC, Heat Pump, and Fridge
    - based on the AMPdS dataset these are actually a substantial portion of the load
    
Tweaking seemingly does a lot to save on loads

'''
# Out:
# "\n1 week of simulation with 10 loads takes roughly 22-23 seconds on my computer\n1 day with 10 loads takes roughly 3 seconds\n\nWith the current buy / sell model (no battery) the price either skews to the left \nor the right, so it's a bit tougher to make highly consistent\n\nAC stays almost consistently on to maintain exact temperature, but if pushed to degree\nor a smaller precision power / ac time can be saved significantly\n\nLoad modelling seems to be relatively functional. Controls will be maintained for only \nsections of the load modelling, such as AC, Heat Pump, and Fridge\n    - based on the AMPdS dataset these are actually a substantial portion of the load\n    \nTweaking seemingly does a lot to save on loads\n\n"

# %%
total_load =  0
        
def run_grid_loads(env, loads):

    global total_load
    total_load= 0
    
    for l in loads:
        total_load+=l.run_load()
    
    return total_load


timestep = 0

def run_simulation(env, num_houses, renewable_sources, num_batteries):
    global timestep
    houses = []
    for i in range(0, num_houses):
        houses.append(House(env))

    while True:
        yield env.timeout(1)  # Wait a bit before generating a new person
        timestep += 1
        run_grid_loads(env, houses)
        #print(get_power(renewable_sources))

ren_power = 0
#replace with probabilistic model sampling
energy_price = 1
total_cost = 0

def get_power(rens):
    global ren_power
    global total_cost
    ren_power = 0
    #would likely get renewables probabilistic cost at this time
    for i in range(0, rens):
        ren_power+=random.randint(220, 290)
    
    if total_load<=ren_power:
        total_cost -= (ren_power-total_load)*energy_price
    else:
        total_cost -= (ren_power-total_load)*energy_price
    
    return total_cost

def main():
    # Setup
    random.seed(42)

    # Run the simulation
    env = simpy.Environment()
    env.process(run_simulation(env, 10, 4, 1))
    #Seconds to run the simulation
    env.run(until=86400)


if __name__ == '__main__':
    main()
# Out:
# tv turned on for 10.416666666666666 minutes
# tv turned on for 107.31666666666666 minutes
# tv turned on for 94.38333333333334 minutes
# tv turned on for 50.75 minutes
# tv turned on for 109.91666666666667 minutes
# tv turned on for 77.91666666666667 minutes
# tv turned on for 25.8 minutes
# tv turned on for 115.33333333333333 minutes
# tv turned on for 100.73333333333333 minutes
# tv turned on for 35.8 minutes
# tv turned on for 16.883333333333333 minutes
# tv turned on for 72.88333333333334 minutes
# tv turned on for 6.45 minutes
# tv turned on for 102.68333333333334 minutes
# tv turned on for 50.8 minutes
# tv turned on for 77.31666666666666 minutes
# tv turned on for 45.31666666666667 minutes
# tv turned on for 75.6 minutes
# tv turned on for 23.45 minutes
# tv turned on for 95.13333333333334 minutes
# tv turned on for 94.48333333333333 minutes
# tv turned on for 70.06666666666666 minutes
# tv turned on for 61.61666666666667 minutes
# tv turned on for 90.43333333333334 minutes
# tv turned on for 49.6 minutes
# tv turned on for 72.98333333333333 minutes
# tv turned on for 39.8 minutes
# tv turned on for 31.733333333333334 minutes
# tv turned on for 7.75 minutes
# tv turned on for 57.95 minutes
# tv turned on for 43.85 minutes
# tv turned on for 13.733333333333333 minutes
# tv turned on for 87.5 minutes
# tv turned on for 55.65 minutes
# tv turned on for 52.483333333333334 minutes
# tv turned on for 48.78333333333333 minutes
# tv turned on for 61.56666666666667 minutes
# tv turned on for 80.11666666666666 minutes
# tv turned on for 76.83333333333333 minutes
# tv turned on for 12.466666666666667 minutes
# tv turned on for 28.033333333333335 minutes
# tv turned on for 85.15 minutes
# tv turned on for 5.116666666666666 minutes
# tv turned on for 91.53333333333333 minutes
# tv turned on for 71.55 minutes
# tv turned on for 5.083333333333333 minutes
# tv turned on for 10.5 minutes
# tv turned on for 43.06666666666667 minutes
# tv turned on for 101.18333333333334 minutes
# tv turned on for 81.7 minutes
# tv turned on for 14.183333333333334 minutes
# tv turned on for 72.0 minutes
# tv turned on for 90.75 minutes
# tv turned on for 71.03333333333333 minutes
# tv turned on for 112.76666666666667 minutes
# tv turned on for 48.85 minutes
# tv turned on for 118.36666666666666 minutes
# tv turned on for 47.4 minutes
# tv turned on for 24.85 minutes
# tv turned on for 13.566666666666666 minutes
# tv turned on for 97.71666666666667 minutes
# tv turned on for 72.71666666666667 minutes
# tv turned on for 7.966666666666667 minutes
# tv turned on for 11.283333333333333 minutes
# tv turned on for 37.733333333333334 minutes
# tv turned on for 72.11666666666666 minutes
# tv turned on for 43.31666666666667 minutes
# tv turned on for 55.93333333333333 minutes
# tv turned on for 16.45 minutes
# tv turned on for 99.18333333333334 minutes
# tv turned on for 15.566666666666666 minutes
# tv turned on for 106.75 minutes
# tv turned on for 80.08333333333333 minutes
# tv turned on for 55.333333333333336 minutes
# tv turned on for 55.81666666666667 minutes
# tv turned on for 116.11666666666666 minutes
# tv turned on for 110.56666666666666 minutes
# tv turned on for 47.11666666666667 minutes
# tv turned on for 15.333333333333334 minutes
# tv turned on for 78.76666666666667 minutes
# tv turned on for 34.13333333333333 minutes
# tv turned on for 83.43333333333334 minutes
# tv turned on for 26.616666666666667 minutes
# tv turned on for 94.08333333333333 minutes
# tv turned on for 84.0 minutes
# tv turned on for 79.88333333333334 minutes
# tv turned on for 61.166666666666664 minutes
# tv turned on for 111.53333333333333 minutes
# tv turned on for 77.36666666666666 minutes
# tv turned on for 108.05 minutes
# tv turned on for 47.333333333333336 minutes
# tv turned on for 75.25 minutes
# tv turned on for 106.93333333333334 minutes
# tv turned on for 67.85 minutes
# tv turned on for 57.11666666666667 minutes
# tv turned on for 81.35 minutes
# tv turned on for 35.5 minutes
# tv turned on for 68.3 minutes
# tv turned on for 48.5 minutes
# tv turned on for 16.966666666666665 minutes
# tv turned on for 116.48333333333333 minutes
# tv turned on for 92.93333333333334 minutes
# tv turned on for 114.58333333333333 minutes
# tv turned on for 33.55 minutes
# tv turned on for 119.7 minutes
# tv turned on for 50.53333333333333 minutes
# tv turned on for 64.73333333333333 minutes
# tv turned on for 101.93333333333334 minutes
# tv turned on for 50.55 minutes
# tv turned on for 79.28333333333333 minutes
# tv turned on for 84.91666666666667 minutes
# tv turned on for 115.36666666666666 minutes
# tv turned on for 86.65 minutes
# tv turned on for 15.366666666666667 minutes
# tv turned on for 45.233333333333334 minutes
# tv turned on for 32.61666666666667 minutes
# tv turned on for 20.05 minutes
# tv turned on for 109.28333333333333 minutes
# tv turned on for 102.63333333333334 minutes
# tv turned on for 32.916666666666664 minutes
# tv turned on for 9.883333333333333 minutes
# tv turned on for 16.933333333333334 minutes
# tv turned on for 65.06666666666666 minutes
# tv turned on for 116.91666666666667 minutes
# tv turned on for 106.81666666666666 minutes
# tv turned on for 98.88333333333334 minutes
# tv turned on for 33.86666666666667 minutes
# tv turned on for 22.85 minutes
# tv turned on for 9.716666666666667 minutes
# tv turned on for 55.083333333333336 minutes
# tv turned on for 17.583333333333332 minutes
# tv turned on for 32.833333333333336 minutes
# tv turned on for 88.51666666666667 minutes
# tv turned on for 63.15 minutes
# tv turned on for 5.933333333333334 minutes
# tv turned on for 55.1 minutes
# tv turned on for 97.98333333333333 minutes
# tv turned on for 117.91666666666667 minutes
# tv turned on for 56.15 minutes
# tv turned on for 83.83333333333333 minutes
# tv turned on for 53.5 minutes
# tv turned on for 115.58333333333333 minutes
# tv turned on for 76.78333333333333 minutes
# tv turned on for 7.933333333333334 minutes
# tv turned on for 42.21666666666667 minutes
# tv turned on for 74.45 minutes
# tv turned on for 108.88333333333334 minutes
# tv turned on for 40.78333333333333 minutes
# tv turned on for 118.1 minutes
# tv turned on for 67.48333333333333 minutes
# tv turned on for 27.766666666666666 minutes
# tv turned on for 16.116666666666667 minutes
# tv turned on for 6.316666666666666 minutes
# tv turned on for 18.233333333333334 minutes
# tv turned on for 108.75 minutes
# tv turned on for 66.35 minutes
# tv turned on for 13.25 minutes
# tv turned on for 41.0 minutes
# tv turned on for 70.41666666666667 minutes
# tv turned on for 95.58333333333333 minutes
# tv turned on for 90.13333333333334 minutes
# tv turned on for 54.85 minutes
# tv turned on for 75.45 minutes
# tv turned on for 98.93333333333334 minutes
# tv turned on for 21.716666666666665 minutes
# tv turned on for 100.7 minutes
# tv turned on for 76.08333333333333 minutes
# tv turned on for 74.53333333333333 minutes
# tv turned on for 52.86666666666667 minutes
# tv turned on for 15.533333333333333 minutes
# tv turned on for 111.26666666666667 minutes
# tv turned on for 69.25 minutes
# tv turned on for 82.66666666666667 minutes
# tv turned on for 50.15 minutes
# tv turned on for 54.38333333333333 minutes
# tv turned on for 10.366666666666667 minutes
# tv turned on for 31.5 minutes
# tv turned on for 108.2 minutes
# tv turned on for 27.5 minutes
# tv turned on for 109.61666666666666 minutes
# tv turned on for 7.65 minutes
# tv turned on for 11.95 minutes
# tv turned on for 119.28333333333333 minutes
# tv turned on for 18.1 minutes
# tv turned on for 88.85 minutes
# tv turned on for 84.31666666666666 minutes
# tv turned on for 34.833333333333336 minutes
# tv turned on for 86.91666666666667 minutes
# tv turned on for 63.11666666666667 minutes
# tv turned on for 100.81666666666666 minutes
# tv turned on for 15.3 minutes
# tv turned on for 96.7 minutes
# tv turned on for 101.43333333333334 minutes
# tv turned on for 54.0 minutes
# tv turned on for 19.266666666666666 minutes
# tv turned on for 119.18333333333334 minutes
# tv turned on for 109.28333333333333 minutes
# tv turned on for 114.63333333333334 minutes
# tv turned on for 109.8 minutes
# tv turned on for 71.06666666666666 minutes
# tv turned on for 117.25 minutes
# tv turned on for 49.13333333333333 minutes
# tv turned on for 27.15 minutes
# tv turned on for 37.233333333333334 minutes
# tv turned on for 42.583333333333336 minutes
# tv turned on for 55.733333333333334 minutes
# tv turned on for 81.23333333333333 minutes
# tv turned on for 10.033333333333333 minutes
# tv turned on for 113.96666666666667 minutes
# tv turned on for 75.53333333333333 minutes
# tv turned on for 86.88333333333334 minutes
# tv turned on for 15.066666666666666 minutes
# tv turned on for 19.483333333333334 minutes
# tv turned on for 73.43333333333334 minutes
# tv turned on for 118.88333333333334 minutes
# tv turned on for 38.21666666666667 minutes
# tv turned on for 92.96666666666667 minutes
# tv turned on for 12.75 minutes
# tv turned on for 98.58333333333333 minutes
# tv turned on for 42.5 minutes
# tv turned on for 81.38333333333334 minutes
# tv turned on for 98.6 minutes
# tv turned on for 81.45 minutes
# tv turned on for 48.916666666666664 minutes
# tv turned on for 29.6 minutes
# tv turned on for 67.08333333333333 minutes
# tv turned on for 25.283333333333335 minutes
# tv turned on for 55.13333333333333 minutes
# tv turned on for 27.2 minutes
# tv turned on for 25.083333333333332 minutes
# tv turned on for 11.85 minutes
# tv turned on for 31.666666666666668 minutes
# tv turned on for 52.016666666666666 minutes
# tv turned on for 80.75 minutes
